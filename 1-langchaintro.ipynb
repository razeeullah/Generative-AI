# %%
import langchain
print(langchain.__version__)

# %%
###langchain version V1

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %%
os.environ['OPENAI_API_KEY'] =os.getenv("OPENAI_API_KEY")

# %%
os.environ['GROK_API_KEY']= os.getenv("GROK_API_KEY")

# %% [markdown]
# ### Generative AI Application with OpenAI Models

# %%
from langchain.chat_models import init_chat_model
model= init_chat_model("gpt-2")
model.invoke("Hello")

# %% [markdown]
# LLM MODEL Integration With Google Gemini

# %%
os.environ['GOOGLE_API_KEY']= os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Hey how are you??")
print(response.content)
# Out:
# Hey there! I'm doing great, thanks for asking! I'm an AI, so I don't experience feelings in the same way humans do, but I'm functioning perfectly and ready to help you with whatever you need.
#
# How about you? How are you doing today?

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("Tell  me  about Sir syed Case IT University Islamabad")
print(response.content)

# %% [markdown]
# GROQ INTEGRATION

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")


model = init_chat_model("groq:llama-3.1-8b-instant")
response = model.invoke("Explain AI in one sentence")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[75], line 7
#       4 os.environ["GROQ_API_KEY"] = "your_real_groq_key_here"
#       6 model = init_chat_model("groq:llama-3.1-8b-instant")
# ----> 7 response = model.invoke("Explain AI in one sentence")
#       8 print(response.content)
#
# File ~/Desktop/LcByKrishbnaik/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
# ...

# %%
import os 
from langchain_groq import ChatGroq
model = ChatGroq(model_name="qwen/qwen3-32b")
response = model.invoke("Explain AI in one sentence")
print(response.content)

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("groq:llama-3.1-8b-instant")

response = model.invoke("Explain Pakistan politics in simple words")
print(response.content)
